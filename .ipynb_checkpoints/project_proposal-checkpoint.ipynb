# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf
import statsmodels.api as sm
import seaborn as sns
import matplotlib.pyplot as plt
from patsy import dmatrix
from sklearn.metrics import mean_squared_error
from pyearth import Earth

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Data Cleaning / Exploration

# %%
sample_size = 20000

path = 'data/heart_2020_cleaned.csv'
df = pd.read_csv(path)
df = df.sample(n = sample_size)
df.head()
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 302398          Yes  29.18      No              No     No            30.0
# 198872           No  25.68     Yes              No     No             0.0
# 78986            No  33.28      No              No     No             7.0
# 51843            No  27.83      No              No     No             0.0
# 43582           Yes  28.59     Yes              No    Yes            30.0
#
#         MentalHealth DiffWalking     Sex AgeCategory      Race Diabetic  \
# 302398           0.0         Yes  Female       65-69     White      Yes
# 198872          20.0          No    Male       30-34     White       No
# 78986            0.0         Yes  Female       75-79     Black       No
# 51843            0.0          No    Male       45-49  Hispanic       No
# 43582            0.0         Yes    Male       65-69     Black       No
#
#        PhysicalActivity GenHealth  SleepTime Asthma KidneyDisease SkinCancer
# 302398               No      Poor        5.0    Yes            No         No
# 198872              Yes      Good        6.0     No            No         No
# 78986               Yes      Good        7.0     No            No         No
# 51843                No      Good        8.0     No            No         No
# 43582                No      Poor        8.0     No            No         No

# %%
df.isna().sum()
# Out:
# HeartDisease        0
# BMI                 0
# Smoking             0
# AlcoholDrinking     0
# Stroke              0
# PhysicalHealth      0
# MentalHealth        0
# DiffWalking         0
# Sex                 0
# AgeCategory         0
# Race                0
# Diabetic            0
# PhysicalActivity    0
# GenHealth           0
# SleepTime           0
# Asthma              0
# KidneyDisease       0
# SkinCancer          0
# dtype: int64

# %%
for col in list(df.columns):
    if df[col].dtype == 'object':
        print(f"Column '{col}' has {len(df[col].unique())} unique values")
# Out:
# Column 'HeartDisease' has 2 unique values
# Column 'Smoking' has 2 unique values
# Column 'AlcoholDrinking' has 2 unique values
# Column 'Stroke' has 2 unique values
# Column 'DiffWalking' has 2 unique values
# Column 'Sex' has 2 unique values
# Column 'AgeCategory' has 13 unique values
# Column 'Race' has 6 unique values
# Column 'Diabetic' has 4 unique values
# Column 'PhysicalActivity' has 2 unique values
# Column 'GenHealth' has 5 unique values
# Column 'Asthma' has 2 unique values
# Column 'KidneyDisease' has 2 unique values
# Column 'SkinCancer' has 2 unique values

# %%
binary_cols = ['HeartDisease', 'Smoking', 'AlcoholDrinking',
              'Stroke', 'DiffWalking', 'PhysicalActivity',
              'Asthma', 'KidneyDisease', 'SkinCancer']

for col in binary_cols:
    print(f"Working on column: {col}")
    df[col] = df.apply(
        lambda row: 1 if row[col] == 'Yes' else 0,
        axis = 1
    )
    
df.head()
# Out:
# Working on column: HeartDisease
# Working on column: Smoking
# Working on column: AlcoholDrinking
# Working on column: Stroke
# Working on column: DiffWalking
# Working on column: PhysicalActivity
# Working on column: Asthma
# Working on column: KidneyDisease
# Working on column: SkinCancer
#         HeartDisease    BMI  Smoking  AlcoholDrinking  Stroke  PhysicalHealth  \
# 302398             1  29.18        0                0       0            30.0
# 198872             0  25.68        1                0       0             0.0
# 78986              0  33.28        0                0       0             7.0
# 51843              0  27.83        0                0       0             0.0
# 43582              1  28.59        1                0       1            30.0
#
#         MentalHealth  DiffWalking     Sex AgeCategory      Race Diabetic  \
# 302398           0.0            1  Female       65-69     White      Yes
# 198872          20.0            0    Male       30-34     White       No
# 78986            0.0            1  Female       75-79     Black       No
# 51843            0.0            0    Male       45-49  Hispanic       No
# 43582            0.0            1    Male       65-69     Black       No
#
#         PhysicalActivity GenHealth  SleepTime  Asthma  KidneyDisease  \
# 302398                 0      Poor        5.0       1              0
# 198872                 1      Good        6.0       0              0
# 78986                  1      Good        7.0       0              0
# 51843                  0      Good        8.0       0              0
# 43582                  0      Poor        8.0       0              0
#
#         SkinCancer
# 302398           0
# 198872           0
# 78986            0
# 51843            0
# 43582            0

# %%
for col in list(df.columns):
    if df[col].dtype == 'object':
        df[col] = df.apply(
            lambda row: row[col].replace(' ', '_'),
            axis = 1
        )

# %%
for col in list(df.columns):
    if df[col].dtype == 'object':
        dummies = pd.get_dummies(
            df[col], prefix = f"{col}", drop_first = True
        )

        df = df.drop(columns = [col])
        df = pd.concat([df, dummies], axis = 1)
        
df.head()
# Out:
#         HeartDisease    BMI  Smoking  AlcoholDrinking  Stroke  PhysicalHealth  \
# 302398             1  29.18        0                0       0            30.0
# 198872             0  25.68        1                0       0             0.0
# 78986              0  33.28        0                0       0             7.0
# 51843              0  27.83        0                0       0             0.0
# 43582              1  28.59        1                0       1            30.0
#
#         MentalHealth  DiffWalking  PhysicalActivity  SleepTime  ...  \
# 302398           0.0            1                 0        5.0  ...
# 198872          20.0            0                 1        6.0  ...
# 78986            0.0            1                 1        7.0  ...
# 51843            0.0            0                 0        8.0  ...
# 43582            0.0            1                 0        8.0  ...
#
#         Race_Hispanic  Race_Other  Race_White  \
# 302398              0           0           1
# 198872              0           0           1
# 78986               0           0           0
# 51843               1           0           0
# 43582               0           0           0
#
#         Diabetic_No,_borderline_diabetes  Diabetic_Yes  \
# 302398                                 0             1
# 198872                                 0             0
# 78986                                  0             0
# 51843                                  0             0
# 43582                                  0             0
#
#         Diabetic_Yes_(during_pregnancy)  GenHealth_Fair  GenHealth_Good  \
# 302398                                0               0               0
# 198872                                0               0               1
# 78986                                 0               0               1
# 51843                                 0               0               1
# 43582                                 0               0               0
#
#         GenHealth_Poor  GenHealth_Very_good
# 302398               1                    0
# 198872               0                    0
# 78986                0                    0
# 51843                0                    0
# 43582                1                    0
#
# [5 rows x 38 columns]

# %%
df.to_csv('data/heart_2020_cleaned_v2.csv')

# %% [markdown]
# # EDA

# %%
sample_size = 20000

path = 'data/heart_2020_cleaned.csv'
df = pd.read_csv(path)
df = df.sample(n = sample_size)
df.head()
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 128939           No  35.25     Yes              No     No             0.0
# 56855            No  14.35      No              No     No             0.0
# 169576           No  39.87     Yes              No     No             0.0
# 73598            No  27.22     Yes              No     No             0.0
# 116911           No  29.24     Yes              No     No             1.0
#
#         MentalHealth DiffWalking     Sex AgeCategory   Race Diabetic  \
# 128939           0.0          No  Female       50-54  White       No
# 56855            0.0          No  Female       65-69  Black       No
# 169576           0.0          No    Male       60-64  White      Yes
# 73598            0.0          No    Male       60-64  White       No
# 116911           1.0          No    Male       55-59  White       No
#
#        PhysicalActivity  GenHealth  SleepTime Asthma KidneyDisease SkinCancer
# 128939              Yes  Very good        8.0     No            No         No
# 56855               Yes  Excellent        7.0     No            No         No
# 169576              Yes  Excellent        8.0     No            No         No
# 73598               Yes       Good        7.0     No            No         No
# 116911              Yes       Good        6.0     No            No        Yes

# %%
binary_cols = ['HeartDisease', 'Smoking', 'AlcoholDrinking',
              'Stroke', 'DiffWalking', 'PhysicalActivity',
              'Asthma', 'KidneyDisease', 'SkinCancer']

for col in binary_cols:
    print(f"Working on column: {col}")
    df[col] = df.apply(
        lambda row: 1 if row[col] == 'Yes' else 0,
        axis = 1
    )
    
df.head()
# Out:
# Working on column: HeartDisease
# Working on column: Smoking
# Working on column: AlcoholDrinking
# Working on column: Stroke
# Working on column: DiffWalking
# Working on column: PhysicalActivity
# Working on column: Asthma
# Working on column: KidneyDisease
# Working on column: SkinCancer
#         HeartDisease    BMI  Smoking  AlcoholDrinking  Stroke  PhysicalHealth  \
# 312258             0  26.97        0                0       0             0.0
# 180696             0  24.69        0                0       0             0.0
# 252413             0  35.43        1                0       0            30.0
# 28504              0  26.61        0                0       0             0.0
# 192566             0  31.66        1                0       0            30.0
#
#         MentalHealth  DiffWalking     Sex AgeCategory      Race  \
# 312258           0.0            0    Male       65-69     White
# 180696           7.0            0  Female       25-29     White
# 252413          30.0            0  Female       35-39     White
# 28504            0.0            0    Male       30-34  Hispanic
# 192566          30.0            1    Male       50-54     White
#
#                        Diabetic  PhysicalActivity GenHealth  SleepTime  \
# 312258                       No                 1      Good        7.0
# 180696                       No                 1      Good        5.0
# 252413  No, borderline diabetes                 0      Fair        7.0
# 28504                        No                 0      Good        8.0
# 192566                       No                 0      Fair        6.0
#
#         Asthma  KidneyDisease  SkinCancer
# 312258       0              0           0
# 180696       1              0           0
# 252413       1              0           0
# 28504        0              0           0
# 192566       1              0           0

# %%
for col in list(df.columns):
    if col == 'HeartDisease':
        continue
    elif df[col].dtype == 'object':
        df.groupby(f'{col}')['HeartDisease'].value_counts().unstack().plot.bar()
    else:
        plt.scatter(df[col], df['HeartDisease'])
        
    plt.xlabel(f"{col}")
    plt.ylabel("HeartDisease")
    plt.show()

# %%
df = pd.read_csv('data/heart_2020_cleaned_v2.csv')
df.corr()['HeartDisease'].sort_values(
    key = lambda x: abs(x),
    ascending = False
)[1:]
# Out:
# DiffWalking                         0.203213
# Stroke                              0.181137
# PhysicalHealth                      0.179915
# Diabetic_Yes                        0.176685
# GenHealth_Poor                      0.176091
# GenHealth_Fair                      0.147506
# KidneyDisease                       0.147311
# AgeCategory_80_or_older             0.144564
# Smoking                             0.111180
# SkinCancer                          0.105995
# PhysicalActivity                   -0.103652
# AgeCategory_75-79                   0.099504
# GenHealth_Very_good                -0.097548
# Sex_Male                            0.077046
# AgeCategory_70-74                   0.071909
# AgeCategory_35-39                  -0.068596
# AgeCategory_30-34                  -0.064913
# AgeCategory_25-29                  -0.062541
# AgeCategory_45-49                  -0.055642
# AgeCategory_40-44                  -0.054274
# Asthma                              0.051822
# BMI                                 0.046209
# AgeCategory_65-69                   0.046007
# Race_Hispanic                      -0.039450
# Race_White                          0.038258
# GenHealth_Good                      0.037185
# AgeCategory_50-54                  -0.034916
# Diabetic_No,_borderline_diabetes    0.023754
# AlcoholDrinking                    -0.023237
# Race_Asian                         -0.023108
# MentalHealth                        0.019030
# AgeCategory_60-64                   0.017206
# AgeCategory_55-59                  -0.007474
# Diabetic_Yes_(during_pregnancy)    -0.006648
# Unnamed: 0                         -0.005886
# SleepTime                           0.005567
# Race_Black                         -0.004244
# Race_Other                         -0.003933
# Name: HeartDisease, dtype: float64
